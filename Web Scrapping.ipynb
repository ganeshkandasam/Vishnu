# %%
from  bs4 import BeautifulSoup as bs

# %%
import pandas as pd

# %%
import requests as re

# %%
url="https://www.amazon.in/s?k=books&crid=1UGZ6AEBS0XLD&sprefix=book%2Caps%2C620&ref=nb_sb_noss_2"

# %%
response=re.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
bc=bs(response.text)

# %%
bc
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
book_name=bc.select(".a-size-medium")

# %%
book_name
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">I Don't Love You Anymore: Moving On and Living Your Best Life | National Bestseller by Rithvik Singh | Original Edition</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Don't Believe Everything You Think (English)</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Dopamine Detox : A Short Guide to Remove Distractions and Get Your Brain to Do Hard Things</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Days at the Morisaki Bookshop : The International Bestseller for lovers of Before the Coffee Gets Cold: A charming and uplifting story on the healing power of books</span>,
#  <span class="a-size-medium a-color-base a-text-normal">The Psychology of Money</span>,
#  <span class="a-size-medium a-color-base a-text-normal">The Power of Your Subconscious Mind</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Amma Diarylo Konni Pageelu</span>,
# ...

# %%
book_data=pd.DataFrame(book_name,columns=["name"])

# %%
book_data
# Out:
#                                                  name
# 0   I Don't Love You Anymore: Moving On and Living...
# 1        Don't Believe Everything You Think (English)
# 2   Dopamine Detox : A Short Guide to Remove Distr...
# 3   Days at the Morisaki Bookshop : The Internatio...
# 4                             The Psychology of Money
# 5                 The Power of Your Subconscious Mind
# 6                          Amma Diarylo Konni Pageelu
# 7   Courage To Be Disliked, The: How to free yours...
# 8   World’s Greatest Books For Personal Growth & W...
# 9   The Art of Laziness: Overcome Procrastination ...
# 10  The Mountain Is You: Transforming Self-Sabotag...
# 11                                      The Alchemist
# 12                                 YOU ONLY LIVE ONCE
# 13  Deep Work: Rules for Focused Success in a Dist...
# 14  The Almanack Of Naval Ravikant: A Guide to Wea...
# 15                           The Theory Of Everything

# %%
book_price=bc.select(".puis-price-instructions-style .a-price-whole")

# %%
book_data["price"]=book_price

# %%
mobile_data
# Out:
#                                                  name  price
# 0   I Don't Love You Anymore: Moving On and Living...  [205]
# 1        Don't Believe Everything You Think (English)  [208]
# 2   Dopamine Detox : A Short Guide to Remove Distr...  [205]
# 3   Days at the Morisaki Bookshop : The Internatio...  [273]
# 4                             The Psychology of Money  [227]
# 5                 The Power of Your Subconscious Mind  [149]
# 6                          Amma Diarylo Konni Pageelu  [200]
# 7   Courage To Be Disliked, The: How to free yours...  [346]
# 8   World’s Greatest Books For Personal Growth & W...  [349]
# 9   The Art of Laziness: Overcome Procrastination ...  [195]
# 10  The Mountain Is You: Transforming Self-Sabotag...  [279]
# 11                                      The Alchemist  [273]
# 12                                 YOU ONLY LIVE ONCE  [179]
# 13  Deep Work: Rules for Focused Success in a Dist...  [267]
# ...
